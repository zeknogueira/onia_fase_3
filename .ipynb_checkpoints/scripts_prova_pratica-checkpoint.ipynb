# %%
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
#xgboost não está incorporado ao Scikit Learn: verificar se não terá problemas com as regras.
import xgboost as xgb


from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN
from imblearn.combine import SMOTETomek
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler



from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
arq_treinamento = pd.read_csv('arquivos/brutos/treino.csv')
arq_teste = pd.read_csv('arquivos/brutos/teste.csv')

# %%
print(arq_treinamento.head())
# Out:
#       id      col_0     col_1     col_2      col_3      col_4     col_5  \
# 0  12251  38.763463  4.372530  2.888516  12.352539  18.906550  9.605924
# 1   4529  32.192181  3.158109  2.134617  16.193530  26.786878  9.347958
# 2  11284  28.370782  3.006067  1.969280  15.163950  28.515109  7.946870
# 3  10993  38.215409  2.174232  2.935104  11.501867  18.419571  7.954005
# 4  12927  38.904545  2.956164  2.253149  12.282552  25.547887  8.168776
#
#       col_6     col_7     col_8     col_9     col_10     col_11    col_12  \
# 0  3.456596  3.959477  4.738227  3.692509  11.192263   9.076242  4.692962
# 1  5.093277  6.893790  3.399840  2.080853  19.486692  12.349952  3.217670
# 2  5.609813  6.511194  3.256799  2.290993  18.405205  14.781329  3.231217
# 3  4.229832  4.522060  4.869234  3.383514  12.782517  17.343742  5.009182
# 4  3.653026  6.809110  4.971130  2.127363  19.247327  20.115183  3.560524
#
#    target
# 0       2
# 1       0
# 2       0
# 3       2
# 4       3

# %%
#informacoes arquivo de treinamento 

#print(arq_treinamento.info())

#print(arq_treinamento.describe())

# %%
# informacoes arquivo de treinamento print (arq_treinamento.isnull().sum())

# %%
#definindo target e características
arq_treinamento_x = arq_treinamento.drop(columns=['target', 'id'])

arq_treinamento_y = arq_treinamento['target']

# %%
#verificando se as classes estão balanceadas

arq_treinamento_y.value_counts()

#classes estão desbalanceadas. Não vou utilizar Acuraccy Score para Medir.
# Out:
# target
# 0    5096
# 4    1609
# 1    1593
# 2    1389
# 3     813
# Name: count, dtype: int64

# %%
#definindo o train_split_test

X_train, X_test, y_train, y_test = train_test_split(arq_treinamento_x, arq_treinamento_y, test_size=0.2, random_state=42)

# %%
y_test.value_counts()
# Out:
# target
# 0    1023
# 1     334
# 4     306
# 2     281
# 3     156
# Name: count, dtype: int64

# %%
#verificando as divisoes:

print("Dados de treinamento (X_train):")
print(X_train)
print("Labels de treinamento (y_train):")
print(y_train)

print("Dados de teste (X_test):")
print(X_test)
print("Labels de teste (y_test):")
print(y_test)
# Out:
# Dados de treinamento (X_train):
#            col_0     col_1     col_2      col_3      col_4      col_5  \
# 2847   27.736039  3.693330  2.019204  17.562488  27.993266  10.817219
# 5790   38.292235  3.294237  2.139664  10.180685  26.734123   6.949034
# 10135  36.572161  2.872531  2.042313  13.140397  27.751711   7.662752
# 9308   29.832711  3.146585  1.767575  15.760194  30.623478   8.993098
# 7920   29.710928  2.750049  1.785853  17.679648  30.432423  10.138858
# ...          ...       ...       ...        ...        ...        ...
# 5734   32.835391  2.483251  1.949526  13.356599  28.721595   6.243580
# 5191   46.532682  2.244092  2.111770   9.770747  27.025688   4.472614
# 5390   39.190863  2.162845  2.118808  15.473629  26.952128   8.731499
# 860    53.439343  2.702667  2.870183   9.341179  19.098176   6.477413
# 7270   37.498176  2.609932  1.869091  16.880907  29.562358  11.169676
#
#           col_6     col_7     col_8     col_9     col_10     col_11    col_12
# 2847   4.087637  5.991205  4.248665  2.576593  16.935353   9.643931  3.565308
# 5790   5.450044  4.451444  3.170236  3.422299  12.582905  19.657501  3.321605
# 10135  4.731897  6.402595  4.099708  2.350640  18.098228  17.990753  3.442437
# 9308   4.680036  5.963340  4.074215  2.591898  16.856586  14.426243  3.402635
# 7920   4.817468  5.738199  3.936963  2.715555  16.220181  11.781355  3.595846
# ...         ...       ...       ...       ...        ...        ...       ...
# 5734   6.463168  7.326898  2.601823  1.842971  20.710959  18.998040  2.809496
# 5191   7.331547  2.428478  2.405192  4.533402   6.864583  14.386423  4.603433
# 5390   6.239613  8.206906  2.195323  1.359631  23.198480  17.052701  2.379352
# 860    5.571315  6.202671  2.998252  2.460447  17.533103  17.653533  3.666707
# 7270   4.015889  6.796851  4.201853  2.134097  19.212674  15.705933  3.022377
#
# [8400 rows x 13 columns]
# Labels de treinamento (y_train):
# 2847     0
# 5790     0
# 10135    2
# 9308     2
# 7920     0
#         ..
# 5734     0
# 5191     0
# 5390     0
# 860      2
# 7270     0
# Name: target, Length: 8400, dtype: int64
# Dados de teste (X_test):
#           col_0     col_1     col_2      col_3      col_4      col_5  \
# 5118  18.456132  0.553605  2.158017  19.027481  26.542282   9.616055
# 8931  31.950936  2.809519  3.165208   9.642894  16.014355   6.472726
# 8515  37.031999  3.578244  1.956020  13.628734  28.653709   9.308077
# 7282  43.220504  2.112102  2.569695  11.401856  22.239109   5.329701
# 7623  30.698231  2.646460  2.094022  13.330151  27.211203   7.348387
# ...         ...       ...       ...        ...        ...        ...
# 617   39.596538  2.512103  1.462929  15.770880  33.807875   8.274207
# 8906  38.593966  2.418010  2.412939  11.574882  23.877643   4.817962
# 8729  46.726415  1.471768  2.248059  14.537753  25.601093   7.977466
# 745   25.205239  2.725470  1.683030  17.399222  31.507217  11.063097
# 2823  33.459693  1.597539  2.042438  15.219459  27.750399   7.858878
#
#          col_6     col_7     col_8     col_9     col_10     col_11    col_12
# 5118  6.021969  5.472508  3.684619  2.861485  15.469151  15.299789  4.423524
# 8931  5.702819  4.740519  3.196438  3.263526  13.400036  18.428128  4.294087
# 8515  3.107109  8.161311  5.000998  1.384675  23.069595  20.449088  2.662027
# 7282  5.867352  4.587508  3.892637  3.347567  12.967518  13.568914  5.073370
# 7623  4.967197  7.139572  3.957747  1.945859  20.181442  20.222493  3.220928
# ...        ...       ...       ...       ...        ...        ...       ...
# 617   3.332586  6.838523  5.971798  2.111208  19.330469  16.004564  4.026985
# 8906  5.452481  5.878414  4.349670  2.638544  16.616525  15.392276  4.735540
# 8729  7.172959  9.123634  1.253256  0.856124  25.789795  19.417378  1.947447
# 745   5.174941  4.169362  3.326605  3.577231  11.785544  13.720190  3.329209
# 2823  5.777982  5.381476  3.659133  2.911484  15.211829  15.880543  4.113714
#
# [2100 rows x 13 columns]
# Labels de teste (y_test):
# 5118    0
# 8931    1
# 8515    0
# 7282    2
# 7623    0
#        ..
# 617     0
# 8906    2
# 8729    0
# 745     2
# 2823    0
# Name: target, Length: 2100, dtype: int64

# %%
#RandomForest: definindo o modelo

modelo_random_forest = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
#RandomForest: treinando o modelo
modelo_random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#RandomForest: fazendo as predições

randomforest_pred = modelo_random_forest.predict(X_test)

# %%
print(len(randomforest_pred))
# Out:
# 2100

# %%
#RandomForest: matriz de confusão
matriz_confusao = confusion_matrix(y_test, randomforest_pred)
print(matriz_confusao)

display = ConfusionMatrixDisplay(confusion_matrix=matriz_confusao)
display.plot(cmap='Blues')
plt.show()
# Out:
# [[954  21  20   9  19]
#  [ 85 204  28   6  11]
#  [ 60  22 165   6  28]
#  [ 66  15  14  55   6]
#  [ 75  20  26   4 181]]

# %%
#RandomForest: verificando o relatório de classificação

print(classification_report(y_test, randomforest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1023
#            1       0.72      0.61      0.66       334
#            2       0.65      0.59      0.62       281
#            3       0.69      0.35      0.47       156
#            4       0.74      0.59      0.66       306
#
#     accuracy                           0.74      2100
#    macro avg       0.71      0.61      0.65      2100
# weighted avg       0.74      0.74      0.73      2100

# %%
#KNN: definindo o modelo

modelo_knn = KNeighborsClassifier(n_neighbors=5)
modelo_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#KNN: treinando o modelo
knn_pred = modelo_knn.predict(X_test)

# %%
#KNN: matriz de confusão
matriz_confusao = confusion_matrix(y_test, knn_pred)
print(matriz_confusao)

display = ConfusionMatrixDisplay(confusion_matrix=matriz_confusao)
display.plot(cmap='Blues')
plt.show()
# Out:
# [[917  41  25  13  27]
#  [ 80 196  27   9  22]
#  [ 64  46 136  10  25]
#  [ 68  25  19  39   5]
#  [ 78  25  37   7 159]]

# %%
#KNN: verificando o relatório de classificação

print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.82      1023
#            1       0.59      0.59      0.59       334
#            2       0.56      0.48      0.52       281
#            3       0.50      0.25      0.33       156
#            4       0.67      0.52      0.58       306
#
#     accuracy                           0.69      2100
#    macro avg       0.61      0.55      0.57      2100
# weighted avg       0.67      0.69      0.67      2100

# %%
#testando diversos modelos de uma vez
random_state_42 = 42
modelos = {
    "Random Forest": RandomForestClassifier(random_state=random_state_42),
    "KNN": KNeighborsClassifier(), #nao precisa do random_state
    "SVM": SVC(random_state=random_state_42), #nao defini o kernel, irá usar automaticamente o RBF
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=random_state_42),
    "Naive Bayes": MultinomialNB(), #nao precisa do random_state
    "Decision Tree": DecisionTreeClassifier(random_state=random_state_42),
    "XGBoost": xgb.XGBClassifier(objective="multi:softmax", num_class=5, random_state=random_state_42),
    "Neural Network": MLPClassifier(max_iter=1000)
}

resultados = []

for name, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    y_pred = modelo.predict(X_test)
    ac_score = accuracy_score(y_test, y_pred) #nao será muito útil por que os dados são multiclasse, mas pode ser interessante verificar diferenças gritantes
    
    f1_balanceada = f1_score(y_test, y_pred, average='weighted')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    f1_micro = f1_score(y_test, y_pred, average='micro')

    resultados.append({
        "Model": name,
        "Accuracy": ac_score,
        "F1 Macro": f1_macro,
        "F1 Micro": f1_micro,
        "F1 Balanceada": f1_balanceada
    })

print(pd.DataFrame(resultados))
# Out:
#                  Model  Accuracy  F1 Macro  F1 Micro  F1 Balanceada
# 0        Random Forest  0.742381  0.649307  0.742381       0.729116
# 1                  KNN  0.689048  0.569223  0.689048       0.673377
# 2                  SVM  0.579524  0.348878  0.579524       0.503798
# 3  Logistic Regression  0.539524  0.328485  0.539524       0.476584
# 4          Naive Bayes  0.513810  0.294803  0.513810       0.447196
# 5        Decision Tree  0.616667  0.525464  0.616667       0.617597
# 6              XGBoost  0.762857  0.679175  0.762857       0.754939
# 7       Neural Network  0.722381  0.608880  0.722381       0.708965

# %%
# testando resultados para dados balanceados

# %%
#Oversampling (aumenta as classes com menos amostras, criando artificialmente amostras das classes menores)
smote_balanceamento = SMOTE(sampling_strategy='auto', random_state=42)
X_train_rebalanceado, y_train_rebalanceado = smote_balanceamento.fit_resample(X_train, y_train)

y_train_rebalanceado.value_counts()
# Out:
# target
# 0    4073
# 2    4073
# 4    4073
# 1    4073
# 3    4073
# Name: count, dtype: int64

# %%
#Oversampling: testando diversos modelos de uma vez
random_state_42 = 42
modelos = {
    "Random Forest": RandomForestClassifier(random_state=random_state_42),
    "KNN": KNeighborsClassifier(), #nao precisa do random_state
    "SVM": SVC(random_state=random_state_42), #nao defini o kernel, irá usar automaticamente o RBF
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=random_state_42),
    "Naive Bayes": MultinomialNB(), #nao precisa do random_state
    "Decision Tree": DecisionTreeClassifier(random_state=random_state_42),
    "XGBoost": xgb.XGBClassifier(objective="multi:softmax", num_class=5, random_state=random_state_42),
    "Neural Network": MLPClassifier(max_iter=1000)
}

resultados = []

for name, modelo in modelos.items():
    modelo.fit(X_train_rebalanceado, y_train_rebalanceado)
    y_pred = modelo.predict(X_test)
    ac_score = accuracy_score(y_test, y_pred) #nao será muito útil por que os dados são multiclasse, mas pode ser interessante verificar diferenças gritantes
    
    f1_balanceada = f1_score(y_test, y_pred, average='weighted')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    f1_micro = f1_score(y_test, y_pred, average='micro')

    resultados.append({
        "Model": name,
        "Accuracy": ac_score,
        "F1 Macro": f1_macro,
        "F1 Micro": f1_micro,
        "F1 Balanceada": f1_balanceada
    })

print(pd.DataFrame(resultados))
# Out:
#                  Model  Accuracy  F1 Macro  F1 Micro  F1 Balanceada
# 0        Random Forest  0.755714  0.688314  0.755714       0.756847
# 1                  KNN  0.631429  0.556304  0.631429       0.645131
# 2                  SVM  0.556190  0.484186  0.556190       0.570335
# 3  Logistic Regression  0.421905  0.360650  0.421905       0.447247
# 4          Naive Bayes  0.448095  0.362493  0.448095       0.461285
# 5        Decision Tree  0.630952  0.559478  0.630952       0.639623
# 6              XGBoost  0.762857  0.701274  0.762857       0.765235
# 7       Neural Network  0.731905  0.667055  0.731905       0.738826

# %%
#Undersampling (diminui o número de amostras das classes maiores para igualar com as menores)

undersampler_balanceamento = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_train_under_rebalanceado, y_train_under_rebalanceado = undersampler_balanceamento.fit_resample(X_train, y_test)

y_train_under_rebalanceado.value_counts()
# Out:
# target
# 0    156
# 1    156
# 2    156
# 3    156
# 4    156
# Name: count, dtype: int64

# %%
#Undersampling: testando diversos modelos de uma vez
random_state_42 = 42
modelos = {
    "Random Forest": RandomForestClassifier(random_state=random_state_42),
    "KNN": KNeighborsClassifier(), #nao precisa do random_state
    "SVM": SVC(random_state=random_state_42), #nao defini o kernel, irá usar automaticamente o RBF
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=random_state_42),
    "Naive Bayes": MultinomialNB(), #nao precisa do random_state
    "Decision Tree": DecisionTreeClassifier(random_state=random_state_42),
    "XGBoost": xgb.XGBClassifier(objective="multi:softmax", num_class=5, random_state=random_state_42),
    "Neural Network": MLPClassifier(max_iter=1000)
}

resultados = []

for name, modelo in modelos.items():
    modelo.fit(X_train_under_rebalanceado, y_train_under_rebalanceado)
    y_pred = modelo.predict(X_test)
    ac_score = accuracy_score(y_test, y_pred) #nao será muito útil por que os dados são multiclasse, mas pode ser interessante verificar diferenças gritantes
    
    f1_balanceada = f1_score(y_test, y_pred, average='weighted')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    f1_micro = f1_score(y_test, y_pred, average='micro')

    resultados.append({
        "Model": name,
        "Accuracy": ac_score,
        "F1 Macro": f1_macro,
        "F1 Micro": f1_micro,
        "F1 Balanceada": f1_balanceada
    })

print(pd.DataFrame(resultados))
# Out:
#                  Model  Accuracy  F1 Macro  F1 Micro  F1 Balanceada
# 0        Random Forest  0.218571  0.194393  0.218571       0.243131
# 1                  KNN  0.226190  0.179050  0.226190       0.251822
# 2                  SVM  0.129048  0.119561  0.129048       0.134591
# 3  Logistic Regression  0.148095  0.138563  0.148095       0.168484
# 4          Naive Bayes  0.157143  0.131117  0.157143       0.176258
# 5        Decision Tree  0.190952  0.171659  0.190952       0.212281
# 6              XGBoost  0.201905  0.185018  0.201905       0.219593
# 7       Neural Network  0.108571  0.109106  0.108571       0.110425

# %%
#Under não rolou

# %%
#melhores resultados:
#Random Forest, XGBoost e NeuralNetWork

# %%
#Oversampling: verificanco matriz de confusão dos três melhores modelos

random_state_42 = 42
modelos = {
    "Random Forest": RandomForestClassifier(random_state=random_state_42),
    "XGBoost": xgb.XGBClassifier(objective="multi:softmax", num_class=5, random_state=random_state_42),
    "Neural Network": MLPClassifier(max_iter=1000)
}

resultados = []

for name, modelo in modelos.items():
    modelo.fit(X_train_rebalanceado, y_train_rebalanceado)
    y_pred = modelo.predict(X_test)
    ac_score = accuracy_score(y_test, y_pred) #nao será muito útil por que os dados são multiclasse, mas pode ser interessante verificar diferenças gritantes
    
    f1_balanceada = f1_score(y_test, y_pred, average='weighted')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    f1_micro = f1_score(y_test, y_pred, average='micro')

    matriz_confusao = confusion_matrix(y_test, y_pred)
    display = ConfusionMatrixDisplay(confusion_matrix=matriz_confusao)
    display.plot(cmap='Blues')
    plt.title(name)
    plt.figure(figsize=(8,6))
    plt.show()

    resultados.append({
        "Model": name,
        "Accuracy": ac_score,
        "F1 Macro": f1_macro,
        "F1 Micro": f1_micro,
        "F1 Balanceada": f1_balanceada
    })

print(pd.DataFrame(resultados))
# Out:
#             Model  Accuracy  F1 Macro  F1 Micro  F1 Balanceada
# 0   Random Forest  0.755714  0.688314  0.755714       0.756847
# 1         XGBoost  0.762857  0.701274  0.762857       0.765235
# 2  Neural Network  0.757619  0.690212  0.757619       0.760091

# %%
#Oversampling SMOTE+Tomek Links: ( Combina o SMOTE com uma técnica de retirada de ruídos)
#verificanco matriz de confusão dos três melhores modelos

random_state_42 = 42
smote_tomek_balanceamento = SMOTETomek(random_state=random_state_42)
X_train_rebalanceado_smotetomek, y_train_rebalanceado_smotetomek = smote_tomek_balanceamento.fit_resample(X_train, y_train)

y_train_rebalanceado_smotetomek.value_counts()


modelos = {
    "Random Forest": RandomForestClassifier(random_state=random_state_42),
    "XGBoost": xgb.XGBClassifier(objective="multi:softmax", num_class=5, random_state=random_state_42),
    "Neural Network": MLPClassifier(max_iter=1000)
}

resultados = []

for name, modelo in modelos.items():
    modelo.fit(X_train_rebalanceado_smotetomek, y_train_rebalanceado_smotetomek)
    y_pred = modelo.predict(X_test)
    ac_score = accuracy_score(y_test, y_pred) #nao será muito útil por que os dados são multiclasse, mas pode ser interessante verificar diferenças gritantes
    
    f1_balanceada = f1_score(y_test, y_pred, average='weighted')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    f1_micro = f1_score(y_test, y_pred, average='micro')

    matriz_confusao = confusion_matrix(y_test, y_pred)
    display = ConfusionMatrixDisplay(confusion_matrix=matriz_confusao)
    display.plot(cmap='Blues')
    plt.title(name)
    plt.figure(figsize=(8,6))
    print(name, matriz_confusao)
    plt.show()

    resultados.append({
        "Model": name,
        "Accuracy": ac_score,
        "F1 Macro": f1_macro,
        "F1 Micro": f1_micro,
        "F1 Balanceada": f1_balanceada
    })

print(pd.DataFrame(resultados))
# Out:
# Random Forest [[873  34  33  39  44]
#  [ 43 236  33  10  12]
#  [ 31  20 189  13  28]
#  [ 40  16  15  80   5]
#  [ 33  18  36  11 208]]
# XGBoost [[866  43  37  41  36]
#  [ 35 237  34  12  16]
#  [ 27  18 190  18  28]
#  [ 29  15  16  88   8]
#  [ 28  25  28  10 215]]
# Neural Network [[886  28  15  57  37]
#  [ 45 233  13  24  19]
#  [ 34  28 145  30  44]
#  [ 27  13   4 108   4]
#  [ 41  16  18  16 215]]
#             Model  Accuracy  F1 Macro  F1 Micro  F1 Balanceada
# 0   Random Forest  0.755238  0.684717  0.755238       0.755572
# 1         XGBoost  0.760000  0.692797  0.760000       0.762255
# 2  Neural Network  0.755714  0.685253  0.755714       0.756340

# %%
#Oversampling SMOTE+Tomek Links: ( Combina o SMOTE com uma técnica de retirada de ruídos)
#verificanco a F1-score com validação cruzada
#matriz de confusão dos três melhores modelos

random_state_42 = 42
smote_tomek_balanceamento = SMOTETomek(random_state=random_state_42)


modelos = {
    "Random Forest": RandomForestClassifier(random_state=random_state_42),
    "XGBoost": xgb.XGBClassifier(objective="multi:softmax", num_class=5, random_state=random_state_42),
    "Neural Network": MLPClassifier(max_iter=1000)
}

#validacao cruzada com stratifieldkfold
validacao_cruzada = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state_42)

resultados = []

for name, modelo in modelos.items():
    f1_macro_scores = []
    f1_micro_scores = []
    f1_balanceada_scores = []
    accuracy_scores = []

    for treino_dados, validacao_dados in validacao_cruzada.split(X_train, y_train):
        X_train_vc, X_val_vc = X_train.iloc[treino_dados], X_train.iloc[validacao_dados]
        y_train_vc, y_val_vc = y_train.iloc[treino_dados], y_train.iloc[validacao_dados]

        X_rebalanceado, y_rebalanceado = smote_tomek_balanceamento.fit_resample(X_train_vc, y_train_vc)

        modelo.fit(X_rebalanceado, y_rebalanceado)

        y_pred = modelo.predict(X_val_vc)

        ac_score = accuracy_score(y_val_vc, y_pred) #nao será muito útil por que os dados são multiclasse, mas pode ser interessante verificar diferenças gritantes
        f1_balanceada = f1_score(y_val_vc, y_pred, average='weighted')
        f1_macro = f1_score(y_val_vc, y_pred, average='macro')
        f1_micro = f1_score(y_val_vc, y_pred, average='micro')

        accuracy_scores.append(ac_score)
        f1_macro_scores.append(f1_macro)
        f1_micro_scores.append(f1_micro)
        f1_balanceada_scores.append(f1_balanceada)

        
        matriz_confusao = confusion_matrix(y_val_vc, y_pred)
        display = ConfusionMatrixDisplay(confusion_matrix=matriz_confusao)
        display.plot(cmap='Blues')
        plt.title(f'{name} - Fold')
        print(name, matriz_confusao)
        plt.show()

    #resultados: média das métricas dos folds
    resultados.append({
        "Model": name,
        "Accuracy": np.mean(accuracy_scores),
        "F1 Macro": np.mean(f1_macro_scores),
        "F1 Micro": np.mean(f1_micro_scores),
        "F1 Balanceada": np.mean(f1_balanceada_scores)
    })

print(pd.DataFrame(resultados))
# Out:
# Random Forest [[705  32  18  30  30]
#  [ 39 163  25  14  11]
#  [ 16  19 155  11  21]
#  [ 20   8  11  82  10]
#  [ 33  21  19   8 179]]
# Random Forest [[687  40  18  35  35]
#  [ 39 167  17  12  17]
#  [ 16  18 154  17  16]
#  [ 17   8  12  88   6]
#  [ 22  15  25   4 195]]
# Random Forest [[698  32  26  19  40]
#  [ 37 177  17  12   9]
#  [ 23  12 148  16  22]
#  [ 24   9   8  79  11]
#  [ 46  16  16   9 174]]
# Random Forest [[703  34  20  26  31]
#  [ 26 168  28  18  11]
#  [ 19  15 149  18  21]
#  [ 24  15   5  76  12]
#  [ 32  15  26   6 182]]
# Random Forest [[697  32  29  24  32]
#  [ 34 176  18  11  13]
#  [ 28  20 140  11  23]
#  [ 31   8  10  73  10]
#  [ 27  22  23  11 177]]
# XGBoost [[699  32  21  30  33]
#  [ 34 165  25  13  15]
#  [ 19  13 155  13  22]
#  [ 24   9  13  78   7]
#  [ 30  22  17  13 178]]
# XGBoost [[662  48  36  28  41]
#  [ 32 175  15  10  20]
#  [ 10  24 154  17  16]
#  [ 18  11   9  86   7]
#  [ 27  16  26   4 188]]
# XGBoost [[690  35  27  20  43]
#  [ 27 180  19  15  11]
#  [ 23  16 145  17  20]
#  [ 23   8  10  83   7]
#  [ 40  20  21  10 170]]
# XGBoost [[690  43  21  27  33]
#  [ 24 174  23  17  13]
#  [ 17  15 153  19  18]
#  [ 23  12   6  80  11]
#  [ 27  17  28   7 182]]
# XGBoost [[683  31  28  29  43]
#  [ 30 178  20  13  11]
#  [ 24  18 141  16  23]
#  [ 26   8  12  80   6]
#  [ 28  15  22   9 186]]
# Neural Network [[653  51  24  60  27]
#  [ 28 178  24  11  11]
#  [ 17  20 153  17  15]
#  [ 19   9  17  81   5]
#  [ 36  32  31   7 154]]
# Neural Network [[624  53  47  33  58]
#  [ 34 167  16  13  22]
#  [  7  23 143  14  34]
#  [ 21  21   5  71  13]
#  [ 25  14  17  10 195]]
# Neural Network [[616  57  46  60  36]
#  [ 18 170  27  30   7]
#  [ 20  11 151  28  11]
#  [ 15   5  12  95   4]
#  [ 38  25  32  20 146]]
# Neural Network [[575  76  34  64  65]
#  [  9 159  36  35  12]
#  [ 14  15 146  34  13]
#  [ 12  13  13  89   5]
#  [ 17  21  25  15 183]]
# Neural Network [[575  53  47  65  74]
#  [ 29 146  23  27  27]
#  [ 18  12 142  24  26]
#  [ 17   9  20  72  14]
#  [ 23  12  28  11 186]]
#             Model  Accuracy  F1 Macro  F1 Micro  F1 Balanceada
# 0   Random Forest  0.760952  0.698569  0.760952       0.761536
# 1         XGBoost  0.756548  0.696636  0.756548       0.758457
# 2  Neural Network  0.698810  0.641369  0.698810       0.707719

# %%
#resultados com validação cruzada são mais confiáveis por oferecerem generalização. 
#RandomForest se mostrou melhor.

# %%
#Aprimorando o balanceamento dos dados
#ADASYN
#usando Pipeline

random_state_42 = 42

balanceador = Pipeline([
    ('adasyn', ADASYN(random_state=random_state_42)),
    ('smote_tomek_balanceamento', SMOTETomek(random_state=random_state_42))
])


modelos = {
    "Random Forest": RandomForestClassifier(random_state=random_state_42),
    "XGBoost": xgb.XGBClassifier(objective="multi:softmax", num_class=5, random_state=random_state_42),
    "Neural Network": MLPClassifier(max_iter=1000)
}

#validacao cruzada com stratifieldkfold
validacao_cruzada = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state_42)

resultados = []

for name, modelo in modelos.items():
    f1_macro_scores = []
    f1_micro_scores = []
    f1_balanceada_scores = []
    accuracy_scores = []

    for treino_dados, validacao_dados in validacao_cruzada.split(X_train, y_train):
        X_train_vc, X_val_vc = X_train.iloc[treino_dados], X_train.iloc[validacao_dados]
        y_train_vc, y_val_vc = y_train.iloc[treino_dados], y_train.iloc[validacao_dados]


        #adicionando o ADASYN
        X_rebalanceado, y_rebalanceado = balanceador.fit_resample(X_train_vc, y_train_vc)

        modelo.fit(X_rebalanceado, y_rebalanceado)

        y_pred = modelo.predict(X_val_vc)

        ac_score = accuracy_score(y_val_vc, y_pred) #nao será muito útil por que os dados são multiclasse, mas pode ser interessante verificar diferenças gritantes
        f1_balanceada = f1_score(y_val_vc, y_pred, average='weighted')
        f1_macro = f1_score(y_val_vc, y_pred, average='macro')
        f1_micro = f1_score(y_val_vc, y_pred, average='micro')

        accuracy_scores.append(ac_score)
        f1_macro_scores.append(f1_macro)
        f1_micro_scores.append(f1_micro)
        f1_balanceada_scores.append(f1_balanceada)

        """
        matriz_confusao = confusion_matrix(y_val_vc, y_pred)
        display = ConfusionMatrixDisplay(confusion_matrix=matriz_confusao)
        display.plot(cmap='Blues')
        plt.title(f'{name} - Fold')
        print(name, matriz_confusao)
        plt.show()
    """
    #resultados: média das métricas dos folds
    """
    resultados.append({
        "Model": name,
        "Accuracy": np.mean(accuracy_scores),
        "F1 Macro": np.mean(f1_macro_scores),
        "F1 Micro": np.mean(f1_micro_scores),
        "F1 Balanceada": np.mean(f1_balanceada_scores)
    })
    """
    # priorizando a métrica f1-score que será cobrada
    resultados.append({
        "Model": name,
      # "Accuracy": np.mean(accuracy_scores),
       # "F1 Macro": np.mean(f1_macro_scores),
       # "F1 Micro": np.mean(f1_micro_scores),
        "F1 Balanceada": np.mean(f1_balanceada_scores)
    })
    

print(pd.DataFrame(resultados))
# Out:
#             Model  F1 Balanceada
# 0   Random Forest       0.757623
# 1         XGBoost       0.748710
# 2  Neural Network       0.693497

# %%
#ADASYN não teve muito efeito

# %%
#Rede Neural também não está performando. Vou seguir somente com RF e XGBoost
